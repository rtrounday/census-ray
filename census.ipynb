# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# Census API Key
from localenv import api_key
c2015 = Census(api_key, year=2015)
from localenv import api_key
c2014 = Census(api_key, year=2014)
from localenv import api_key
c2013 = Census(api_key, year=2013)
from localenv import api_key
c2012 = Census(api_key, year=2012)
from localenv import api_key
c2011 = Census(api_key, year=2011)

# %%
# Run Census Search to retrieve data on all states
# Note the addition of "B23025_005E" for unemployment count
census_data_2013 = c2013.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

census_pd_2013 = pd.DataFrame(census_data_2013)

census_pd_2013 = census_pd_2013.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Final DataFrame
census_pd_2013 = census_pd_2013[["Name", "Population"]]

census_pd_2013
# Out:
#                     Name  Population
# 0                Alabama   4799277.0
# 1                 Alaska    720316.0
# 2                Arizona   6479703.0
# 3               Arkansas   2933369.0
# 4             California  37659181.0
# 5               Colorado   5119329.0
# 6            Connecticut   3583561.0
# 7               Delaware    908446.0
# 8   District of Columbia    619371.0
# 9                Florida  19091156.0
# 10               Georgia   9810417.0
# 11                Hawaii   1376298.0
# 12                 Idaho   1583364.0
# 13              Illinois  12848554.0
# 14               Indiana   6514861.0
# 15                  Iowa   3062553.0
# 16                Kansas   2868107.0
# 17              Kentucky   4361333.0
# 18             Louisiana   4567968.0
# 19                 Maine   1328320.0
# 20              Maryland   5834299.0
# 21         Massachusetts   6605058.0
# 22              Michigan   9886095.0
# 23             Minnesota   5347740.0
# ...

# %%
census_data_2011 = c2011.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

census_pd_2011 = pd.DataFrame(census_data_2011)

census_pd_2011 = census_pd_2011.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Final DataFrame
census_pd_2011 = census_pd_2011[["Name", "Population"]]

census_pd_2011

# %%
census_data_2012 = c2012.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

census_pd_2012 = pd.DataFrame(census_data_2012)

census_pd_2012 = census_pd_2012.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Final DataFrame
census_pd_2012 = census_pd_2012[["Name", "Population"]]

census_pd_2012
# Out:
#                     Name  Population
# 0                Alabama   4777326.0
# 1                 Alaska    711139.0
# 2                Arizona   6410979.0
# 3               Arkansas   2916372.0
# 4             California  37325068.0
# 5               Colorado   5042853.0
# 6            Connecticut   3572213.0
# 7               Delaware    900131.0
# 8   District of Columbia    605759.0
# 9                Florida  18885152.0
# 10               Georgia   9714569.0
# 11                Hawaii   1362730.0
# 12                 Idaho   1567803.0
# 13              Illinois  12823860.0
# 14               Indiana   6485530.0
# 15                  Iowa   3047646.0
# 16                Kansas   2851183.0
# 17              Kentucky   4340167.0
# 18             Louisiana   4529605.0
# 19                 Maine   1329084.0
# 20              Maryland   5785496.0
# 21         Massachusetts   6560595.0
# 22              Michigan   9897264.0
# 23             Minnesota   5313081.0
# ...

# %%
census_data_2013 = c2013.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

census_pd_2013 = pd.DataFrame(census_data_2013)

census_pd_2013 = census_pd_2013.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Final DataFrame
census_pd_2013 = census_pd_2013[["Name", "Population"]]

census_pd_2013
# Out:
#                     Name  Population
# 0                Alabama   4799277.0
# 1                 Alaska    720316.0
# 2                Arizona   6479703.0
# 3               Arkansas   2933369.0
# 4             California  37659181.0
# 5               Colorado   5119329.0
# 6            Connecticut   3583561.0
# 7               Delaware    908446.0
# 8   District of Columbia    619371.0
# 9                Florida  19091156.0
# 10               Georgia   9810417.0
# 11                Hawaii   1376298.0
# 12                 Idaho   1583364.0
# 13              Illinois  12848554.0
# 14               Indiana   6514861.0
# 15                  Iowa   3062553.0
# 16                Kansas   2868107.0
# 17              Kentucky   4361333.0
# 18             Louisiana   4567968.0
# 19                 Maine   1328320.0
# 20              Maryland   5834299.0
# 21         Massachusetts   6605058.0
# 22              Michigan   9886095.0
# 23             Minnesota   5347740.0
# ...

# %%
census_data_2014 = c2014.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

census_pd_2014 = pd.DataFrame(census_data_2014)

census_pd_2014 = census_pd_2014.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Final DataFrame
census_pd_2014 = census_pd_2014[["Name", "Population"]]

census_pd_2014
# Out:
#                     Name  Population
# 0                Alabama   4817678.0
# 1                 Alaska    728300.0
# 2                Arizona   6561516.0
# 3               Arkansas   2947036.0
# 4             California  38066920.0
# 5               Colorado   5197580.0
# 6            Connecticut   3592053.0
# 7               Delaware    917060.0
# 8   District of Columbia    633736.0
# 9                Florida  19361792.0
# 10               Georgia   9907756.0
# 11                Hawaii   1392704.0
# 12                 Idaho   1599464.0
# 13              Illinois  12868747.0
# 14               Indiana   6542411.0
# 15                  Iowa   3078116.0
# 16                Kansas   2882946.0
# 17              Kentucky   4383272.0
# 18             Louisiana   4601049.0
# 19                 Maine   1328535.0
# 20              Maryland   5887776.0
# 21         Massachusetts   6657291.0
# 22              Michigan   9889024.0
# 23             Minnesota   5383661.0
# ...

# %%
census_data_2015 = c2015.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
                          "B19301_001E",
                          "B17001_002E",
                          "B23025_005E"), {'for': 'state:*'})

census_pd_2015 = pd.DataFrame(census_data_2015)

census_pd_2015 = census_pd_2015.rename(columns={"B01003_001E": "Population",
                                      "B01002_001E": "Median Age",
                                      "B19013_001E": "Household Income",
                                      "B19301_001E": "Per Capita Income",
                                      "B17001_002E": "Poverty Count",
                                      "B23025_005E": "Unemployment Count",
                                      "NAME": "Name", "state": "State"})

# Final DataFrame
census_pd_2015 = census_pd_2015[["Name", "Population"]]

census_pd_2015
# Out:
#                     Name  Population
# 0                 Alaska    733375.0
# 1                Alabama   4830620.0
# 2               Arkansas   2958208.0
# 3                Arizona   6641928.0
# 4             California  38421464.0
# 5               Colorado   5278906.0
# 6            Connecticut   3593222.0
# 7   District of Columbia    647484.0
# 8               Delaware    926454.0
# 9                Florida  19645772.0
# 10               Georgia  10006693.0
# 11                Hawaii   1406299.0
# 12                  Iowa   3093526.0
# 13                 Idaho   1616547.0
# 14              Illinois  12873761.0
# 15               Indiana   6568645.0
# 16                Kansas   2892987.0
# 17              Kentucky   4397353.0
# 18             Louisiana   4625253.0
# 19         Massachusetts   6705586.0
# 20              Maryland   5930538.0
# 21                 Maine   1329100.0
# 22              Michigan   9900571.0
# 23             Minnesota   5419171.0
# ...
